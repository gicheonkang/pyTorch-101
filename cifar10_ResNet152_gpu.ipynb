# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torchvision.transforms as transforms
import torchvision.datasets as dsets
import numpy as np


#hyper parameters
batch_size = 50
learning_rate = 0.001
num_class = 10
num_epoch = 10

# cifar10 dataset
train_dataset = dsets.CIFAR10(root='./data', 
                              train=True,
                              transform=transforms.ToTensor(),
                              download=True)

test_dataset = dsets.CIFAR10(root='./data',
                            train=True,
                            transform=transforms.ToTensor(),
                            download=True)


train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)


test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                         batch_size=batch_size,
                                         shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# each block's channel 
cfg = {
    'cfg_0' : [64, 64, 256],
    'cfg_1' : [128, 128, 512],
    'cfg_2' : [256, 256, 1024],
    'cfg_3' : [512, 512, 2048]
}

# %%
class bottleNeck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, cfg, stride=1):
        super(bottleNeck, self).__init__()
        self.unit = nn.Sequential(
                        nn.Conv2d(in_channel, cfg[0], kernel_size=1, bias=False),
                        nn.BatchNorm2d(cfg[0]),   
                        nn.ReLU(inplace=True),
                        nn.Conv2d(cfg[0], cfg[1], kernel_size=3, padding=1, stride=stride, bias=False),
                        nn.BatchNorm2d(cfg[1]), 
                        nn.ReLU(inplace=True),
                        nn.Conv2d(cfg[1], cfg[2], kernel_size=1, bias=False),
                        nn.BatchNorm2d(cfg[2]) 
                    )
        self.stride = stride
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channel != self.expansion * cfg[0]:
            self.shortcut = nn.Sequential(
                                nn.Conv2d(in_channel, self.expansion * cfg[0], kernel_size=1, stride=stride, bias=False),
                                nn.BatchNorm2d(self.expansion * cfg[0])
                            )
        
    def forward(self, x):
        out = self.unit(x)
        residual = self.shortcut(x)
        out += residual
        out = F.relu(out)
        return out

# %%
class resNet152(nn.Module):
    def __init__(self, block, cfg, num_block):
        super(resNet152, self).__init__()
        self.in_ch = 64
        self.go = nn.Sequential(
                    nn.Conv2d(3, 64, kernel_size=3, padding=1, stride=1, bias=False),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True)
                )
        self.cfg_0 = self.make_residual_block(block, cfg['cfg_0'], num_block[0], stride=1)
        self.cfg_1 = self.make_residual_block(block, cfg['cfg_1'], num_block[1], stride=2)
        self.cfg_2 = self.make_residual_block(block, cfg['cfg_2'], num_block[2], stride=2)
        self.cfg_3 = self.make_residual_block(block, cfg['cfg_3'], num_block[3], stride=2)
        self.fc = nn.Linear(1 * 1 * 2048, 1000)

    def forward(self, image):
        out = self.go(image)
        out = self.cfg_0(out)
        out = self.cfg_1(out)
        out = self.cfg_2(out)
        out = self.cfg_3(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out
        
    def make_residual_block(self, block, cfg, num_block, stride):
        strides = [stride] + [1]*(num_block-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_ch, cfg, stride))
            self.in_ch = cfg[0] * block.expansion
        return nn.Sequential(*layers)

# %%
MODEL = resNet152(bottleNeck, cfg, num_block=[3, 8, 36, 3])
MODEL.cuda(1)
print (MODEL)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(MODEL.parameters(), lr=learning_rate)
# Out:
# resNet152(
#   (go): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (2): ReLU(inplace)
#   )
#   (cfg_0): Sequential(
#     (0): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (2): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (cfg_1): Sequential(
#     (0): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (2): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (3): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (4): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (5): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (6): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (7): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (cfg_2): Sequential(
#     (0): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (2): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (3): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (4): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (5): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (6): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (7): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (8): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (9): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (10): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (11): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (12): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (13): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (14): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (15): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (16): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (17): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (18): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (19): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (20): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (21): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (22): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (23): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (24): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (25): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (26): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (27): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (28): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (29): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (30): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (31): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (32): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (33): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (34): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (35): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (cfg_3): Sequential(
#     (0): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#     (2): bottleNeck(
#       (unit): Sequential(
#         (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (5): ReLU(inplace)
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# training session
batch_count = 0

for epoch in range(num_epoch):
    for i, (image, label) in enumerate(train_loader):
        images = Variable(image.cuda(1))
        labels = Variable(label.cuda(1))
        
        optimizer.zero_grad()
        out = MODEL(images)
        loss = criterion(out, labels)
        loss.backward()
        optimizer.step()
        
        if(i+1) % 100 == 0:
            batch_count += 1
            print('training... %d%%, Loss: %.4f' % ( ((batch_size * 100) * batch_count * 100) / (num_epoch * len(train_dataset)), loss.data[0]))
# Out:
# training... 1%, Loss: 2.0195
# training... 2%, Loss: 1.9498
# training... 3%, Loss: 1.5976
# training... 4%, Loss: 1.6562
# training... 5%, Loss: 1.7822
# training... 6%, Loss: 1.5308
# training... 7%, Loss: 1.3791
# training... 8%, Loss: 1.2847
# training... 9%, Loss: 1.4335
# training... 10%, Loss: 1.2289
# training... 11%, Loss: 1.2006
# training... 12%, Loss: 1.0834
# training... 13%, Loss: 1.0114
# training... 14%, Loss: 1.0561
# training... 15%, Loss: 1.1488
# training... 16%, Loss: 1.3212
# training... 17%, Loss: 1.0230
# training... 18%, Loss: 0.9633
# training... 19%, Loss: 1.2706
# training... 20%, Loss: 1.0237
# training... 21%, Loss: 0.8851
# training... 22%, Loss: 0.9199
# training... 23%, Loss: 0.8458
# training... 24%, Loss: 1.2557
# training... 25%, Loss: 0.8571
# training... 26%, Loss: 0.6821
# training... 27%, Loss: 0.6420
# training... 28%, Loss: 0.9060
# training... 29%, Loss: 0.8498
# training... 30%, Loss: 0.6302
# training... 31%, Loss: 0.7148
# training... 32%, Loss: 1.1695
# training... 33%, Loss: 0.6594
# training... 34%, Loss: 0.5795
# training... 35%, Loss: 0.8636
# training... 36%, Loss: 0.4049
# training... 37%, Loss: 0.6920
# training... 38%, Loss: 0.5288
# training... 39%, Loss: 1.0049
# training... 40%, Loss: 0.5484
# training... 41%, Loss: 0.4598
# training... 42%, Loss: 0.4467
# training... 43%, Loss: 0.5337
# training... 44%, Loss: 0.6421
# training... 45%, Loss: 0.6430
# training... 46%, Loss: 0.6167
# training... 47%, Loss: 0.2866
# training... 48%, Loss: 0.6504
# training... 49%, Loss: 0.5109
# training... 50%, Loss: 0.5432
# training... 51%, Loss: 0.6761
# training... 52%, Loss: 0.5213
# training... 53%, Loss: 0.3435
# training... 54%, Loss: 0.6159
# training... 55%, Loss: 0.6657
# training... 56%, Loss: 0.3902
# training... 57%, Loss: 0.5520
# training... 58%, Loss: 0.3676
# training... 59%, Loss: 0.5019
# training... 60%, Loss: 0.2756
# training... 61%, Loss: 0.2432
# training... 62%, Loss: 0.4903
# training... 63%, Loss: 0.4800
# training... 64%, Loss: 0.3908
# training... 65%, Loss: 0.3546
# training... 66%, Loss: 0.3185
# training... 67%, Loss: 0.3441
# training... 68%, Loss: 0.4080
# training... 69%, Loss: 0.2273
# training... 70%, Loss: 0.3940
# training... 71%, Loss: 0.2672
# training... 72%, Loss: 0.3372
# training... 73%, Loss: 0.3094
# training... 74%, Loss: 0.3404
# training... 75%, Loss: 0.5564
# training... 76%, Loss: 0.4433
# training... 77%, Loss: 0.4869
# training... 78%, Loss: 0.6243
# training... 79%, Loss: 0.2318
# training... 80%, Loss: 0.4107
# training... 81%, Loss: 0.5769
# training... 82%, Loss: 0.4292
# training... 83%, Loss: 0.2944
# training... 84%, Loss: 0.2454
# training... 85%, Loss: 0.3191
# training... 86%, Loss: 0.2795
# training... 87%, Loss: 0.2006
# training... 88%, Loss: 0.1497
# training... 89%, Loss: 0.4443
# training... 90%, Loss: 0.2712
# training... 91%, Loss: 0.3024
# training... 92%, Loss: 0.1164
# training... 93%, Loss: 0.1620
# training... 94%, Loss: 0.1703
# training... 95%, Loss: 0.2065
# training... 96%, Loss: 0.1543
# training... 97%, Loss: 0.2035
# training... 98%, Loss: 0.1752
# training... 99%, Loss: 0.0878
# training... 100%, Loss: 0.1688

# %%
total = 0
correct = 0

for (image, label) in test_loader:
    images = Variable(image.cuda(1))
    
    output = MODEL(images)
    _, predicted = torch.max(output.data, 1)
    correct += (predicted.cpu()==label).sum()
    total += labels.size(0)

print('Accuracy : %d%%' %((100*correct)/total))
# Out:
# Accuracy : 95%
